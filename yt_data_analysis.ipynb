# %%
# first we need to import packages for out project 

import pandas as pd
import os

# %%
files = [file for file in os.listdir('./videos_data')]    # to upload the csv folder to our project
all_videos_data = pd.DataFrame()                          # assining variable for DataFrame

for file in files:                                        # uploading all the csv files from the folder
   df = pd.read_csv("./videos_data/" + file)
   all_videos_data = pd.concat([all_videos_data, df])

all_videos_data.to_csv("all_videos_data.csv",index = False) # declaring the file in .csv format

# %%
all_videos_data = pd.read_csv("all_videos_data.csv")       # displays content in the all_videos_data file
all_videos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280113 entries, 0 to 280112
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   title          280113 non-null  object
#  1   channel_title  280113 non-null  object
#  2   category_id    280113 non-null  int64
#  3   publish_time   280113 non-null  object
#  4   views          280113 non-null  int64
#  5   likes          280113 non-null  int64
#  6   dislikes       280113 non-null  int64
#  7   comment_count  280113 non-null  int64
#  8   region         280113 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 19.2+ MB

# %%
files = [file for file in os.listdir('./category_data')]   # to upload the csv folder to our project
all_category_data = pd.DataFrame()                         # assining variable for DataFrame
 
for file in files:                                         # uploading all the csv files from the folder
   df = pd.read_csv("./category_data/" + file)
   all_category_data = pd.concat([all_category_data, df])  

all_category_data.to_csv("all_category_data.csv",index = False)  # declaring the file in .csv format

# %%
all_category_data = pd.read_csv("all_category_data.csv")         # displays content in the all_category_data file
all_category_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             217 non-null    int64
#  1   snippet/title  217 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.5+ KB

# %%
all_category_data              # data in all_category_data
# Out:
#      id     snippet/title
# 0     1  Film & Animation
# 1     2  Autos & Vehicles
# 2    10             Music
# 3    15    Pets & Animals
# 4    17            Sports
# ..   ..               ...
# 212  40    Sci-Fi/Fantasy
# 213  41          Thriller
# 214  42            Shorts
# 215  43             Shows
# 216  44          Trailers
#
# [217 rows x 2 columns]

# %%
all_videos_data.rename(columns = {'category_id' : 'id'}, inplace = True)   # renaming category_id to id

# %%
#all_videos_data = pd.merge(df1,all_videos_data, on= 'id', how = 'inner')  # inner join like SQL to select only the same id

# %%
all_videos_data.sample(100)         # rondamly picks values for display
# Out:
#                                                     title  \
# 140387                 iKON - ‘사랑을 했다(LOVE SCENARIO)’ M/V
# 254173  Grammys 2018: Hillary Clinton surprises crowd ...
# 180200  Sridevi is no more || Sridevi Death Mystery ||...
# 198497  #DeepthiSunaina Cheema joke chepthe navvali..N...
# 13340   Soca Kingdom (Official Audio) | Machel Montano...
# ...                                                   ...
# 101800  Héros : Ce chien s’est sacrifié pour protéger ...
# 89295   Ce que Laeti­cia Hally­day a dit à ses proches...
# 265752  Meghan Trainor Watches Fan Covers On YouTube |...
# 81675   I Can See Your Voice -TH | EP.121 |  Joey Boy ...
# 105352   Quand Cristiano marque le but il saute comment ?
#
#                          channel_title  id              publish_time  \
# 140387                            iKON  10  2018-01-25T09:00:03.000Z
# 254173                        CBS News  25  2018-01-29T04:34:55.000Z
# ...

# %%
all_videos_data                   # the final data which is being cleaned
# Out:
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 280108                       The Cat Who Caught the Laser
# 280109                         True Facts : Ant Mutualism
# 280110  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 280111                How Black Panther Should Have Ended
# 280112  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  id              publish_time     views  \
# 0                     EminemVEVO  10  2017-11-10T17:00:03.000Z  17158579
# 1                      iDubbbzTV  23  2017-11-13T17:00:00.000Z   1014651
# ...

# %%
#all_videos_data.to_csv('final_data.csv')          # declaring the final data to .csv

# %%
all_videos_data.sample(10)
# Out:
#                                                     title  \
# 83741          Nouvelle Star - Kamisa Negra - DKR (Booba)
# 178948  Kundali Bhagya - Episode 158  - February 16, 2...
# 53930   【ENG SUB 全球】《歌手2018》第2期 20180119 苏诗丁抢先踢馆！首轮淘汰赛...
# 140913                                    To Our Daughter
# 23395   Social Media: Are You Taking it too Serious? H...
# 68987   Sozialer Brennpunkt Frankfurter Berg: Unterweg...
# 165043                              Ab School Hoga Band !
# 20821   The Thin Line Between Genius and Madness | 5 U...
# 71590       گفتم این دوتا محشرن محشر نبینی ضرر کردی😂😂👏👏👏👏
# 197222           AMERICA VS. INDIA | Part 3 | Rickshawali
#
#                                       channel_title  id  \
# 83741                                       M6 Buzz  24
# 178948                                     Ditto TV  24
# 53930   湖南卫视芒果TV官方频道 China HunanTV Official Channel  24
# 140913                                 Kylie Jenner  22
# ...

# %%
#all_videos_data = all_videos_data[all_videos_data['likes']>all_videos_data['dislikes']]

# %%
all_videos_data
# Out:
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 280108                       The Cat Who Caught the Laser
# 280109                         True Facts : Ant Mutualism
# 280110  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 280111                How Black Panther Should Have Ended
# 280112  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  id              publish_time     views  \
# 0                     EminemVEVO  10  2017-11-10T17:00:03.000Z  17158579
# 1                      iDubbbzTV  23  2017-11-13T17:00:00.000Z   1014651
# ...

# %%
df =all_videos_data  # assining new variable df (to keep the original data safe)

# %%
df
# Out:
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 280108                       The Cat Who Caught the Laser
# 280109                         True Facts : Ant Mutualism
# 280110  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 280111                How Black Panther Should Have Ended
# 280112  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  id              publish_time     views  \
# 0                     EminemVEVO  10  2017-11-10T17:00:03.000Z  17158579
# 1                      iDubbbzTV  23  2017-11-13T17:00:00.000Z   1014651
# ...

# %%
all_videos_data.drop_duplicates()  # removes duplicates in the table
# Out:
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 280108                       The Cat Who Caught the Laser
# 280109                         True Facts : Ant Mutualism
# 280110  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 280111                How Black Panther Should Have Ended
# 280112  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  id              publish_time     views  \
# 0                     EminemVEVO  10  2017-11-10T17:00:03.000Z  17158579
# 1                      iDubbbzTV  23  2017-11-13T17:00:00.000Z   1014651
# ...

# %%
all_videos_data['pr'] = all_videos_data['views']/ all_videos_data['likes']   # Creates a new column 'pr' which stores ratio of positive responses

# %%
all_videos_data['nr'] = all_videos_data['views']/ all_videos_data['dislikes']  # Creates a new column 'pr' which stores ratio of negative responses

# %%
all_videos_data
# Out:
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 280108                       The Cat Who Caught the Laser
# 280109                         True Facts : Ant Mutualism
# 280110  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 280111                How Black Panther Should Have Ended
# 280112  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  id              publish_time     views  \
# 0                     EminemVEVO  10  2017-11-10T17:00:03.000Z  17158579
# 1                      iDubbbzTV  23  2017-11-13T17:00:00.000Z   1014651
# ...

# %%
all_videos_data['vr'] = all_videos_data ['views']- all_videos_data ['dislikes'] + all_videos_data['likes'] 
# shows only data which are just viewed bt not liked and disliked

# %%
all_videos_data[all_videos_data['vr']< 0]  # displayes values greater than 0
# Out:
# Empty DataFrame
# Columns: [title, channel_title, id, publish_time, views, likes, dislikes, comment_count, region, pr, nr, vr]
# Index: []

# %%
all_videos_data
# Out:
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 280108                       The Cat Who Caught the Laser
# 280109                         True Facts : Ant Mutualism
# 280110  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 280111                How Black Panther Should Have Ended
# 280112  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                    channel_title  id              publish_time     views  \
# 0                     EminemVEVO  10  2017-11-10T17:00:03.000Z  17158579
# 1                      iDubbbzTV  23  2017-11-13T17:00:00.000Z   1014651
# ...

# %%
#all_videos_data.to_csv('final_data.csv')  # commites final data
